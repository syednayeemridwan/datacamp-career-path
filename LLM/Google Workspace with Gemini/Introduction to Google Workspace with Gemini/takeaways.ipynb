# %% [markdown]
# - Generative AI = AI that Generates content for you
# - Hallucination = biased or unreal information from AI that the AI gives with confidence

# %% [markdown]
# # Quiz Question 1

# %% [markdown]
# Which option best defines generative AI?

# %% [markdown]
# - A subset of AI that refers to the use of AI to create new content, like text, images, music, audio, and videos. (generating contents)

# %% [markdown]
# # Quiz Question 2

# %% [markdown]
# Which tool is best to use with Gemini if you want to create an icon for your presentation?

# %% [markdown]
# - Google Slides

# %% [markdown]
# # Quiz Question 3

# %% [markdown]
# What challenges can generative AI tools like Gemini help you solve?

# %% [markdown]
# - Organize information into formatted tables within a spreadsheet.
