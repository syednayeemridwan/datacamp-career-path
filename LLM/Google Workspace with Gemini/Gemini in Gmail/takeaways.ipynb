# %% [markdown]
# # Key Steps

# %% [markdown]
# <img src="images/01.JPG" />
# <img src="images/02.JPG" />
# <img src="images/03.JPG" />
# <img src="images/04.JPG" />
# <img src="images/05.JPG" />

# %% [markdown]
# - Create draft with AI using 'help me write' and then 'create' button
# - you can edit the prompt for updated response in 'help me write' box with 'update' button
# - Click 'insert' to include the draft in the gmail
# - Refine with:
#     - Formalize: Formal speech with professional tone
#     - Elaborate: Explain the result
#     - Shorten: Summarize the result response further to shorten the answer

# %% [markdown]
# # Quiz Question 1

# %% [markdown]
# You’d like to use Gemini to write an email to your colleagues inviting them to a fun team-building event. Which of the following are details you might include in the prompt to create the most relevant email? (Select two).

# %% [markdown]
# - The tone
# - The recipient

# %% [markdown]
# # Quiz Question 2

# %% [markdown]
# You are writing an email to your CFO who you do not work with frequently. You drafted an email, but you want to make sure it is not too casual. Which Gemini option can you choose to improve the tone of your email?

# %% [markdown]
# - Formalize
